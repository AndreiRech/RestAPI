# %% [markdown]
# # LIMPEZA DOS DADOS
#
# Por conta da grande quantidade de informações que *não são utilizadas e nem relevantes* no contexto do trabalho, é necessário realizar uma **limpeza dos dados** antes de começar a utilizar o dataset propriamente.

# %%
import pandas as pd

# %% [markdown]
# Primeiro, vizualizamos as informações contidas no dataset utilizando a biblioteca **pandas**

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('games.csv')
df.head()
# Out:
#      AppID                   Name  Release date Estimated owners  Peak CCU  \
# 0    20200       Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370           Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930           Jolt Project  Nov 17, 2021        0 - 20000         0
# 3  1355720               Henosis™  Jul 23, 2020        0 - 20000         0
# 4  1139950  Two Weeks in Painland   Feb 3, 2020        0 - 20000         0
#
#    Required age  Price  DiscountDLC count  error  \
# 0             0  19.99                  0      0
# 1             0   0.99                  0      0
# 2             0   4.99                  0      0
# 3             0   5.99                  0      0
# 4             0   0.00                  0      0
#
#                                       About the game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# ...

# %% [markdown]
# Após isso, selecionamos as colunas **indesejadas** e removemos elas do dataset.

# %%
colunas_droppar = ["AppID","Required age", "Score rank", "Notes", "User score","error","Peak CCU", "Supported languages", "Recommendations", "DiscountDLC count", "Full audio languages", "Reviews", "Header image", "Website", "Support url", "Support email", "Windows", "Mac", "Linux", "Metacritic url", "Screenshots", "Movies", "Average playtime two weeks", "Median playtime forever", "Median playtime two weeks", "Developers", "Publishers"]

# %%
novo = df.drop(columns=colunas_droppar)

novo.head()
# Out:
#                     Name  Release date Estimated owners  Price  \
# 0       Galactic Bowling  Oct 21, 2008        0 - 20000  19.99
# 1           Train Bandit  Oct 12, 2017        0 - 20000   0.99
# 2           Jolt Project  Nov 17, 2021        0 - 20000   4.99
# 3               Henosis™  Jul 23, 2020        0 - 20000   5.99
# 4  Two Weeks in Painland   Feb 3, 2020        0 - 20000   0.00
#
#                                       About the game  Metacritic score  \
# 0  Galactic Bowling is an exaggerated and stylize...                 0
# 1  THE LAW!! Looks to be a showdown atop a train....                 0
# 2  Jolt Project: The army now has a new robotics ...                 0
# 3  HENOSIS™ is a mysterious 2D Platform Puzzler w...                 0
# 4  ABOUT THE GAME Play as a hacker who has arrang...                 0
#
#    Positive  Negative  Achievements  Average playtime forever  \
# 0         6        11            30                         0
# ...

# %% [markdown]
# Num último momento, apenas finalizamos testando um caso e salvamos como um arquivo que será utilizado no restante do trabalho.

# %%
print(novo[novo['Name'] == "Counter-Strike: Global Offensive"])
# Out:
#                                    Name  Release date      Estimated owners  \
# 46158  Counter-Strike: Global Offensive  Aug 21, 2012  50000000 - 100000000
#
#        Price                                     About the game  \
# 46158    0.0  Counter-Strike: Global Offensive (CS: GO) expa...
#
#        Metacritic score  Positive  Negative  Achievements  \
# 46158                83   5764420    766677           167
#
#        Average playtime forever  \
# 46158                     30484
#
#                                               Categories               Genres  \
# 46158  Multi-player,Steam Achievements,Full controlle...  Action,Free to Play
#
#                                                     Tags
# 46158  FPS,Shooter,Multiplayer,Competitive,Action,Tea...

# %%
novo = novo.drop(novo.index[46500:])
novo = novo.drop(novo.index[15000:30000])
novo.tail()
# Out:
#                                              Name  Release date  \
# 46495                              Stay Safe 2020   Dec 7, 2021
# 46496  BOT.vinnik Chess: Early USSR Championships   Sep 2, 2021
# 46497                                  Corpse Mob   Jun 4, 2018
# 46498                              Exo-Adventures  Sep 10, 2018
# 46499                        The Fielder's Choice  Feb 22, 2018
#
#       Estimated owners  Price  \
# 46495        0 - 20000   0.00
# 46496        0 - 20000   0.99
# 46497        0 - 20000   1.99
# 46498        0 - 20000   0.99
# 46499        0 - 20000   3.99
#
#                                           About the game  Metacritic score  \
# 46495  In a world where news of the pandemic, endless...                 0
# 46496  Improve your chess knowledge and learn some hi...                 0
# 46497  Kill thousands of zombies in single player and...                 0
# 46498  Join the exploration in this fast-paced space ...                 0
# ...

# %%
caminho = "app\static\games.csv"
novo.to_csv(caminho, index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_16872\3696314711.py:1: SyntaxWarning: invalid escape sequence '\s'
#   caminho = "app\static\games.csv"
